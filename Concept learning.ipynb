# %%
from IPython.lib import kernel

kernel.get_connection_file()
# Out:
# '/run/user/1000/jupyter/kernel-cf852721-0121-4e17-8bd8-b00f921f02d9.json'

# %%
from gensim.corpora import Dictionary
from utilities.LabeledDocuments import LabeledDocument
from gensim import corpora
from os.path import isfile

# inspired by http://radimrehurek.com/gensim/tut1.html#corpus-formats

class MyCorpus():
    def __init__(self, path='samples/', \
                 dictFile='data/MMCorpus/econstor.dict', \
                 corpusFile='data/MMCorpus/corpus.mm', \
                 worker = 4):
        self.path = path
        self.worker = worker
        
        if isfile(dictFile):
            self.dictionary = Dictionary.load(dictFile)
        else:
            labeledDocs = LabeledDocument(wd=self.path, workers=self.worker)
            
            # because LabeledDocument yields gensim.models.doc2vec.LabeledSentence
            # objects and we are only interested in the words property
            docGen = (d.words for d in labeledDocs)
            dictionary = Dictionary(iter(docGen))
            dictionary.save(dictFile)
            self.dictionary = dictionary
            
        if isfile(corpusFile):
            self.corpus = corpora.MmCorpus(corpusFile)
        else:
            corpora.MmCorpus.serialize(corpusFile, self)
            self.corpus = corpora.MmCorpus(corpusFile)
            
    
    def __getitem__(self, name):
        if name == 'dictionary':
            return self.dictionary
        elif name == 'corpus':
            return self.corpus
        else:
            raise AttributeError('This object has no attribute {}.'.format(name))
    
    def __len__(self):
        return len(self.corpus)
    
    def __iter__(self):
        labeledDocs = LabeledDocument(wd=self.path, workers=self.worker)
        for d in labeledDocs:
            yield self.dictionary.doc2bow(d.words)

# %%
from gensim.models.ldamulticore import LdaMulticore

LDAFile = 'data/LDA/LDAModel.lda'
numTopics = 50
lda = ""
if isfile(LDAFile):
    lda = LdaMulticore.load(LDAFile)
else:
    myCorpus = MyCorpus(path='data/samples')
    lda = LdaMulticore(myCorpus, id2word=myCorpus.dictionary,\
                       num_topics=numTopics, workers=4, passes=10, \
                       batch=True)
    lda.save(LDAFile)
# Out:
# INFO:gensim.utils:loading Dictionary object from data/MMCorpus/econstor.dict
# INFO:gensim.corpora.indexedcorpus:loaded corpus index from data/MMCorpus/corpus.mm.index
# INFO:gensim.matutils:initializing corpus reader from data/MMCorpus/corpus.mm
# INFO:gensim.matutils:accepted corpus with 5005 documents, 874774 features, 7669943 non-zero entries
# INFO:gensim.models.ldamodel:using symmetric alpha at 0.02
# INFO:gensim.models.ldamodel:using symmetric eta at 0.02
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running batch LDA training, 50 topics, 10 passes over the supplied corpus of 5005 documents, updating every 5005 documents, evaluating every ~5005 documents, iterating 50x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 4 processes
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 2
# INFO:gensim.models.ldamodel:topic #28 (0.020): 0.006*effect + 0.005*model + 0.004*market + 0.004*economic + 0.004*price + 0.004*result + 0.004*datum + 0.004*level + 0.003*year + 0.003*firm
# INFO:gensim.models.ldamodel:topic #19 (0.020): 0.004*country + 0.004*level + 0.004*economic + 0.004*firm + 0.004*policy + 0.004*effect + 0.004*rate + 0.004*also + 0.003*time + 0.003*result
# INFO:gensim.models.ldamodel:topic #48 (0.020): 0.007*economic + 0.005*effect + 0.004*model + 0.004*datum + 0.004*time + 0.003*result + 0.003*country + 0.003*policy + 0.003*rate + 0.003*individual
# INFO:gensim.models.ldamodel:topic #0 (0.020): 0.005*market + 0.005*economic + 0.004*country + 0.004*datum + 0.004*also + 0.004*effect + 0.004*rate + 0.004*price + 0.004*table + 0.004*model
# INFO:gensim.models.ldamodel:topic #2 (0.020): 0.005*economic + 0.004*market + 0.004*that + 0.004*result + 0.004*time + 0.004*model + 0.004*price + 0.004*effect + 0.003*level + 0.003*datum
# INFO:gensim.models.ldamodel:topic diff=21.259218, rho=1.000000
# INFO:gensim.models.ldamodel:-10.055 per-word bound, 1063.7 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #13 (0.020): 0.011*price + 0.010*model + 0.009*market + 0.003*economic + 0.003*effect + 0.003*datum + 0.003*table + 0.003*also + 0.003*result + 0.003*time
# INFO:gensim.models.ldamodel:topic #23 (0.020): 0.008*effect + 0.006*income + 0.004*economic + 0.004*change + 0.004*datum + 0.004*result + 0.004*household + 0.004*also + 0.003*price + 0.003*table
# INFO:gensim.models.ldamodel:topic #41 (0.020): 0.007*country + 0.006*market + 0.005*economic + 0.005*rate + 0.004*effect + 0.004*price + 0.004*model + 0.004*datum + 0.004*result + 0.003*wage
# INFO:gensim.models.ldamodel:topic #29 (0.020): 0.007*effect + 0.006*economic + 0.006*income + 0.005*household + 0.005*rate + 0.005*country + 0.004*level + 0.004*result + 0.004*model + 0.004*year
# INFO:gensim.models.ldamodel:topic #36 (0.020): 0.005*model + 0.004*market + 0.004*economic + 0.004*also + 0.003*service + 0.003*rate + 0.003*policy + 0.003*country + 0.003*case + 0.003*result
# INFO:gensim.models.ldamodel:topic diff=6.200422, rho=0.471274
# INFO:gensim.models.ldamodel:-9.414 per-word bound, 682.0 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #21 (0.020): 0.005*model + 0.005*economic + 0.004*market + 0.004*price + 0.004*effect + 0.004*area + 0.004*city + 0.003*variable + 0.003*case + 0.003*2014
# INFO:gensim.models.ldamodel:topic #46 (0.020): 0.011*student + 0.008*effect + 0.006*school + 0.004*estimate + 0.004*year + 0.004*economic + 0.004*result + 0.004*model + 0.004*study + 0.004*datum
# INFO:gensim.models.ldamodel:topic #48 (0.020): 0.007*economic + 0.004*datum + 0.004*effect + 0.004*model + 0.004*policy + 0.003*time + 0.003*result + 0.003*individual + 0.003*also + 0.003*level
# INFO:gensim.models.ldamodel:topic #43 (0.020): 0.007*economic + 0.007*that + 0.006*effect + 0.004*country + 0.004*datum + 0.004*with + 0.004*thi + 0.004*group + 0.003*service + 0.003*also
# INFO:gensim.models.ldamodel:topic #39 (0.020): 0.008*effect + 0.007*language + 0.006*labor + 0.005*market + 0.005*model + 0.005*country + 0.004*individual + 0.004*table + 0.004*economic + 0.004*year
# INFO:gensim.models.ldamodel:topic diff=4.849493, rho=0.426305
# INFO:gensim.models.ldamodel:-9.178 per-word bound, 579.1 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #48 (0.020): 0.007*economic + 0.005*datum + 0.004*model + 0.004*effect + 0.004*policy + 0.003*result + 0.003*time + 0.003*individual + 0.003*energy + 0.003*also
# INFO:gensim.models.ldamodel:topic #16 (0.020): 0.005*model + 0.004*group + 0.004*effect + 0.004*game + 0.003*also + 0.003*economic + 0.003*equilibrium + 0.003*income + 0.003*result + 0.003*level
# INFO:gensim.models.ldamodel:topic #33 (0.020): 0.013*that + 0.008*with + 0.005*thi + 0.004*model + 0.004*from + 0.004*price + 0.004*market + 0.004*economic + 0.004*which + 0.004*information
# INFO:gensim.models.ldamodel:topic #41 (0.020): 0.007*country + 0.006*market + 0.005*rate + 0.005*economic + 0.004*debt + 0.004*farm + 0.004*effect + 0.004*result + 0.004*datum + 0.004*model
# INFO:gensim.models.ldamodel:topic #0 (0.020): 0.008*organic + 0.007*market + 0.005*price + 0.004*bond + 0.004*rate + 0.004*datum + 0.004*result + 0.004*country + 0.003*also + 0.003*effect
# INFO:gensim.models.ldamodel:topic diff=3.711535, rho=0.392157
# INFO:gensim.models.ldamodel:-9.041 per-word bound, 526.7 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #43 (0.020): 0.008*economic + 0.006*that + 0.006*effect + 0.005*service + 0.004*datum + 0.004*group + 0.004*with + 0.004*country + 0.003*also + 0.003*thi
# INFO:gensim.models.ldamodel:topic #25 (0.020): 0.008*tourism + 0.005*effect + 0.005*crop + 0.004*organic + 0.004*result + 0.004*economic + 0.003*model + 0.003*development + 0.003*treatment + 0.003*system
# INFO:gensim.models.ldamodel:topic #13 (0.020): 0.023*price + 0.017*model + 0.013*market + 0.006*forecast + 0.004*datum + 0.004*volatility + 0.004*time + 0.004*result + 0.004*economic + 0.003*value
# INFO:gensim.models.ldamodel:topic #48 (0.020): 0.006*economic + 0.005*datum + 0.004*model + 0.004*effect + 0.004*policy + 0.003*result + 0.003*individual + 0.003*energy + 0.003*research + 0.003*also
# INFO:gensim.models.ldamodel:topic #9 (0.020): 0.012*country + 0.010*labmy + 0.009*immigrant + 0.008*migration + 0.006*economic + 0.006*migrant + 0.005*population + 0.005*immigration + 0.004*employment + 0.004*income
# INFO:gensim.models.ldamodel:topic diff=2.789154, rho=0.365088
# INFO:gensim.models.ldamodel:-8.953 per-word bound, 495.6 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #45 (0.020): 0.008*skill + 0.007*effect + 0.005*test + 0.005*economic + 0.005*variable + 0.005*model + 0.005*child + 0.005*result + 0.005*health + 0.004*education
# INFO:gensim.models.ldamodel:topic #26 (0.020): 0.016*wage + 0.011*worker + 0.010*labor + 0.009*effect + 0.008*employment + 0.006*work + 0.006*market + 0.005*unemployment + 0.005*economic + 0.004*datum
# INFO:gensim.models.ldamodel:topic #48 (0.020): 0.006*economic + 0.005*datum + 0.004*model + 0.004*policy + 0.004*effect + 0.003*network + 0.003*research + 0.003*individual + 0.003*result + 0.003*scenario
# INFO:gensim.models.ldamodel:topic #42 (0.020): 0.015*school + 0.014*health + 0.007*education + 0.007*effect + 0.006*year + 0.006*table + 0.005*country + 0.005*level + 0.005*teacher + 0.005*result
# INFO:gensim.models.ldamodel:topic #21 (0.020): 0.006*area + 0.006*city + 0.005*economic + 0.005*2014 + 0.005*price + 0.005*effect + 0.004*disaster + 0.004*model + 0.004*market + 0.004*2013
# INFO:gensim.models.ldamodel:topic diff=2.083941, rho=0.342947
# INFO:gensim.models.ldamodel:-8.894 per-word bound, 475.6 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #32 (0.020): 0.012*school + 0.012*household + 0.008*effect + 0.006*choice + 0.006*table + 0.005*cohort + 0.005*student + 0.005*income + 0.004*level + 0.004*datum
# INFO:gensim.models.ldamodel:topic #38 (0.020): 0.070*portugal + 0.046*turkey + 0.034*italy + 0.027*united + 0.022*france + 0.022*kingdom + 0.018*china + 0.015*germany + 0.012*spain + 0.011*zealand
# INFO:gensim.models.ldamodel:topic #36 (0.020): 0.011*internet + 0.011*network + 0.011*service + 0.010*mobile + 0.007*acces + 0.007*user + 0.007*market + 0.007*broadband + 0.006*operator + 0.005*provider
# INFO:gensim.models.ldamodel:topic #21 (0.020): 0.006*area + 0.006*2014 + 0.006*city + 0.005*economic + 0.005*disaster + 0.005*price + 0.005*effect + 0.004*2013 + 0.004*model + 0.004*market
# INFO:gensim.models.ldamodel:topic #27 (0.020): 0.006*country + 0.006*economic + 0.006*development + 0.005*social + 0.005*policy + 0.005*region + 0.004*regional + 0.004*also + 0.004*change + 0.004*level
# INFO:gensim.models.ldamodel:topic diff=1.559902, rho=0.324400
# INFO:gensim.models.ldamodel:-8.851 per-word bound, 461.9 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #0 (0.020): 0.013*organic + 0.007*market + 0.006*bond + 0.005*food + 0.004*datum + 0.004*result + 0.004*price + 0.004*value + 0.003*system + 0.003*yield
# INFO:gensim.models.ldamodel:topic #18 (0.020): 0.024*fund + 0.009*market + 0.009*risk + 0.009*portfolio + 0.009*return + 0.008*investor + 0.006*country + 0.005*stock + 0.005*trade + 0.004*table
# INFO:gensim.models.ldamodel:topic #42 (0.020): 0.019*health + 0.016*school + 0.008*education + 0.007*effect + 0.006*year + 0.006*table + 0.006*teacher + 0.006*level + 0.005*result + 0.005*country
# INFO:gensim.models.ldamodel:topic #34 (0.020): 0.013*policy + 0.013*rate + 0.010*economic + 0.009*financial + 0.009*country + 0.008*monetary + 0.007*growth + 0.007*market + 0.006*price + 0.005*economy
# INFO:gensim.models.ldamodel:topic #2 (0.020): 0.006*cost + 0.006*immigrant + 0.005*price + 0.005*time + 0.004*economic + 0.004*year + 0.004*market + 0.003*emission + 0.003*state + 0.003*rate
# INFO:gensim.models.ldamodel:topic diff=1.174290, rho=0.308570
# INFO:gensim.models.ldamodel:-8.821 per-word bound, 452.1 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #43 (0.020): 0.008*economic + 0.007*service + 0.005*effect + 0.004*journal + 0.004*datum + 0.004*group + 0.004*that + 0.003*also + 0.003*table + 0.003*treatment
# INFO:gensim.models.ldamodel:topic #5 (0.020): 0.026*city + 0.013*urban + 0.012*region + 0.009*spatial + 0.008*local + 0.007*area + 0.007*water + 0.006*population + 0.005*space + 0.005*level
# INFO:gensim.models.ldamodel:topic #45 (0.020): 0.010*skill + 0.008*effect + 0.006*test + 0.005*variable + 0.005*economic + 0.005*health + 0.005*child + 0.005*study + 0.005*education + 0.005*result
# INFO:gensim.models.ldamodel:topic #19 (0.020): 0.008*energy + 0.006*time + 0.006*knowledge + 0.004*trust + 0.004*board + 0.004*poverty + 0.003*woman + 0.003*donor + 0.003*sovereign + 0.003*economic
# INFO:gensim.models.ldamodel:topic #32 (0.020): 0.014*school + 0.014*household + 0.008*effect + 0.006*choice + 0.006*cohort + 0.006*table + 0.005*student + 0.005*wave + 0.005*income + 0.005*level
# INFO:gensim.models.ldamodel:topic diff=0.890765, rho=0.294852
# INFO:gensim.models.ldamodel:-8.797 per-word bound, 444.9 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #0 = documents up to #2000/5005, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #1 = documents up to #4000/5005, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #2 = documents up to #5005/5005, outstanding queue size 3
# INFO:gensim.models.ldamodel:topic #33 (0.020): 0.016*that + 0.009*with + 0.007*consumer + 0.007*thi + 0.006*equilibrium + 0.006*price + 0.005*model + 0.005*product + 0.005*information + 0.005*type
# INFO:gensim.models.ldamodel:topic #47 (0.020): 0.008*country + 0.008*confidence + 0.004*homelessnes + 0.004*risk + 0.004*income + 0.004*gender + 0.003*table + 0.003*mission + 0.003*economic + 0.003*assessment
# INFO:gensim.models.ldamodel:topic #25 (0.020): 0.012*tourism + 0.010*crop + 0.008*agricultural + 0.007*organic + 0.006*production + 0.006*farmer + 0.006*climate + 0.005*food + 0.005*agriculture + 0.005*effect
# INFO:gensim.models.ldamodel:topic #16 (0.020): 0.009*game + 0.006*player + 0.006*equilibrium + 0.005*group + 0.004*function + 0.004*utility + 0.004*model + 0.004*distribution + 0.004*case + 0.003*proposal
# INFO:gensim.models.ldamodel:topic #9 (0.020): 0.020*country + 0.016*migration + 0.015*immigrant + 0.013*migrant + 0.011*labmy + 0.007*economic + 0.007*immigration + 0.006*population + 0.005*education + 0.005*employment
# INFO:gensim.models.ldamodel:topic diff=0.681441, rho=0.282814
# INFO:gensim.models.ldamodel:-8.779 per-word bound, 439.4 perplexity estimate based on a held-out corpus of 1005 documents with 5943351 words
# INFO:gensim.utils:saving LdaState object under data/LDA/LDAModel.lda.state, separately None
# INFO:gensim.utils:storing numpy array 'sstats' to data/LDA/LDAModel.lda.state.sstats.npy
# INFO:gensim.utils:saving LdaMulticore object under data/LDA/LDAModel.lda, separately None
# INFO:gensim.utils:not storing attribute state
# INFO:gensim.utils:not storing attribute dispatcher
# INFO:gensim.utils:storing numpy array 'expElogbeta' to data/LDA/LDAModel.lda.expElogbeta.npy

# %%
myCorpus = MyCorpus(path='data/samples')
# Out:
# INFO:gensim.utils:loading Dictionary object from data/MMCorpus/econstor.dict
# INFO:gensim.corpora.indexedcorpus:loaded corpus index from data/MMCorpus/corpus.mm.index
# INFO:gensim.matutils:initializing corpus reader from data/MMCorpus/corpus.mm
# INFO:gensim.matutils:accepted corpus with 5005 documents, 874774 features, 7669943 non-zero entries

# %%
'print words of all topics'
words = []
for topic in range(1,numTopics):
    words = [myCorpus.dictionary[word[0]] for word in lda.get_topic_terms(topic)]
    print(words)
# Out:
# ['effect', 'offshoring', 'para', 'cost', 'variable', 'task', 'group', 'datum', 'trade', 'breastfeeding']
# ['cost', 'immigrant', 'price', 'time', 'year', 'economic', 'market', 'reform', 'emission', 'state']
# ['treatment', 'subject', 'experiment', 'group', 'decision', 'participant', 'game', 'economic', 'individual', 'behavior']
# ['market', 'bank', 'policy', 'economic', 'development', 'government', 'state', 'service', 'also', 'company']
# ['city', 'region', 'urban', 'spatial', 'local', 'area', 'water', 'population', 'space', 'level']
# ['firm', 'loan', 'sector', 'table', 'result', 'variable', 'effect', 'cost', 'economic', 'export']
# ['test', 'assumption', 'function', 'estimator', 'rating', 'theorem', 'model', 'result', 'distribution', 'lemma']
# ['table', 'column', 'waste', 'coin', 'feedstock', 'cost', 'area', 'european', 'price', 'value']
# ['country', 'migration', 'immigrant', 'migrant', 'labmy', 'economic', 'immigration', 'population', 'education', 'employment']
# ['bank', 'banking', 'financial', 'risk', 'model', 'economic', 'asset', 'capital', 'credit', 'variable']
# ['firm', 'change', 'cost', 'rate', 'insurance', 'time', 'model', 'effect', 'case', 'group']
# ['cartel', 'case', 'price', 'effect', 'product', 'cost', 'economic', 'competition', 'rate', 'policy']
# ['price', 'model', 'market', 'forecast', 'datum', 'time', 'volatility', 'series', 'result', 'value']
# ['program', 'start', 'sell', 'switch', 'elp', 'market', 'order', 'time', 'policy', 'price']
# ['that', 'with', 'thi', 'from', 'which', 'have', 'more', 'their', 'between', 'other']
# ['game', 'player', 'equilibrium', 'group', 'function', 'utility', 'model', 'distribution', 'case', 'proposal']
# ['that', 'with', 'model', 'thi', 'from', 'rate', 'which', 'effect', 'result', 'value']
# ['fund', 'risk', 'return', 'market', 'investor', 'portfolio', 'stock', 'asset', 'bond', 'investment']
# ['energy', 'time', 'knowledge', 'board', 'trust', 'poverty', 'woman', 'donor', 'sovereign', 'loan']
# ['firm', 'industry', 'variable', 'effect', 'economic', 'trade', 'datum', 'country', 'productivity', 'rate']
# ['disaster', '2014', 'area', 'economic', 'price', 'city', '2013', 'effect', 'merger', 'market']
# ['paper', 'wood', 'moldova', 'product', 'paperboard', 'coffee', 'sme', 'system', 'excl', 'fibre']
# ['income', 'household', 'effect', 'inequality', 'datum', 'individual', 'year', 'change', 'economic', 'table']
# ['rate', 'price', 'financial', 'bank', 'cost', 'model', 'market', 'asset', 'policy', 'economic']
# ['tourism', 'crop', 'agricultural', 'organic', 'production', 'farmer', 'climate', 'food', 'agriculture', 'effect']
# ['wage', 'worker', 'labor', 'employment', 'effect', 'work', 'unemployment', 'market', 'economic', 'individual']
# ['development', 'economic', 'social', 'country', 'policy', 'region', 'regional', 'innovation', 'also', 'research']
# ['effect', 'palm', 'level', 'crop', 'yield', 'result', 'variable', 'change', 'table', 'individual']
# ['income', 'household', 'model', 'rate', 'effect', 'economic', 'consumption', 'result', 'increase', 'level']
# ['energy', 'cost', 'emission', 'transport', 'power', 'electricity', 'economic', 'renewable', 'effect', 'market']
# ['political', 'election', 'party', 'vote', 'candidate', 'voter', 'state', 'social', 'democracy', 'electoral']
# ['school', 'household', 'effect', 'choice', 'cohort', 'table', 'student', 'wave', 'income', 'level']
# ['that', 'with', 'consumer', 'thi', 'equilibrium', 'price', 'model', 'product', 'information', 'type']
# ['rate', 'policy', 'economic', 'financial', 'monetary', 'country', 'growth', 'market', 'price', 'economy']
# ['financial', 'country', 'economic', 'literacy', 'table', 'percent', 'education', 'trust', 'effect', 'also']
# ['network', 'service', 'internet', 'mobile', 'acces', 'user', 'market', 'broadband', 'provider', 'operator']
# ['firm', 'agent', 'equilibrium', 'information', 'effort', 'economic', 'contract', 'effect', 'incentive', 'case']
# ['portugal', 'turkey', 'italy', 'united', 'france', 'kingdom', 'china', 'germany', 'spain', 'zealand']
# ['language', 'effect', 'treatment', 'individual', 'year', 'immigrant', 'labor', 'english', 'earning', 'country']
# ['market', 'globalization', 'rent', 'housing', 'tenant', 'care', 'index', 'increase', 'social', 'year']
# ['farm', 'debt', 'agriholding', 'country', 'market', 'land', 'typical', 'independent', 'pension', 'rate']
# ['health', 'school', 'education', 'effect', 'year', 'table', 'teacher', 'level', 'result', 'datum']
# ['economic', 'service', 'effect', 'journal', 'group', 'datum', 'also', 'that', 'table', 'treatment']
# ['country', 'variable', 'economic', 'effect', 'bank', 'growth', 'government', 'policy', 'result', 'level']
# ['skill', 'effect', 'test', 'variable', 'economic', 'health', 'child', 'study', 'education', 'score']
# ['student', 'school', 'effect', 'education', 'university', 'estimate', 'year', 'college', 'study', 'result']
# ['country', 'confidence', 'homelessnes', 'risk', 'income', 'gender', 'table', 'mission', 'economic', 'assessment']
# ['economic', 'datum', 'model', 'network', 'policy', 'climate', 'research', 'scenario', 'effect', 'case']
# ['child', 'care', 'family', 'parent', 'year', 'mother', 'effect', 'birth', 'income', 'survey']

# %%
'print most frequent words'
from itertools import chain
words = []
for topic in range(1,numTopics):
    words.append([myCorpus.dictionary[word[0]] for word in lda.get_topic_terms(topic)])

words = chain(*words)
wordCount = {}
for word in words:
    if word in wordCount:
        wordCount[word] += 1
    else:
        wordCount[word] = 1
        
sortedWords = sorted(wordCount.items(), key=lambda x: x[1])
for a in reversed(sortedWords):
    print(a)
# Out:
# ('effect', 24)
# ('economic', 23)
# ('market', 13)
# ('model', 10)
# ('country', 9)
# ('price', 9)
# ('table', 9)
# ('result', 9)
# ('cost', 8)
# ('policy', 8)
# ('rate', 8)
# ('year', 7)
# ('datum', 7)
# ('variable', 7)
# ('level', 6)
# ('time', 5)
# ('individual', 5)
# ('case', 5)
# ('group', 5)
# ('education', 5)
# ('income', 5)
# ('financial', 4)
# ('also', 4)
# ('firm', 4)
# ('bank', 4)
# ('that', 4)
# ('risk', 3)
# ('treatment', 3)
# ('value', 3)
# ('service', 3)
# ('with', 3)
# ('product', 3)
# ('area', 3)
# ('school', 3)
# ('immigrant', 3)
# ('equilibrium', 3)
# ('social', 3)
# ('thi', 3)
# ('household', 3)
# ('change', 3)
# ('asset', 3)
# ('state', 3)
# ('climate', 2)
# ('research', 2)
# ('trade', 2)
# ('government', 2)
# ('which', 2)
# ('care', 2)
# ('growth', 2)
# ('loan', 2)
# ('trust', 2)
# ('function', 2)
# ('health', 2)
# ('child', 2)
# ('network', 2)
# ('game', 2)
# ('labor', 2)
# ('increase', 2)
# ('city', 2)
# ('employment', 2)
# ('emission', 2)
# ('crop', 2)
# ('distribution', 2)
# ('region', 2)
# ('student', 2)
# ('study', 2)
# ('test', 2)
# ('development', 2)
# ('population', 2)
# ('energy', 2)
# ('from', 2)
# ('information', 2)
# ('yield', 1)
# ('portfolio', 1)
# ('electricity', 1)
# ('cartel', 1)
# ('sme', 1)
# ('european', 1)
# ('palm', 1)
# ('industry', 1)
# ('consumption', 1)
# ('transport', 1)
# ('have', 1)
# ('portugal', 1)
# ('switch', 1)
# ('feedstock', 1)
# ('language', 1)
# ('space', 1)
# ('kingdom', 1)
# ('series', 1)
# ('democracy', 1)
# ('cohort', 1)
# ('gender', 1)
# ('effort', 1)
# ('merger', 1)
# ('investor', 1)
# ('urban', 1)
# ('parent', 1)
# ('agriculture', 1)
# ('homelessnes', 1)
# ('their', 1)
# ('type', 1)
# ('independent', 1)
# ('housing', 1)
# ('production', 1)
# ('wood', 1)
# ('lemma', 1)
# ('pension', 1)
# ('subject', 1)
# ('export', 1)
# ('more', 1)
# ('percent', 1)
# ('mother', 1)
# ('assumption', 1)
# ('proposal', 1)
# ('reform', 1)
# ('score', 1)
# ('capital', 1)
# ('electoral', 1)
# ('regional', 1)
# ('china', 1)
# ('immigration', 1)
# ('theorem', 1)
# ('column', 1)
# ('moldova', 1)
# ('wage', 1)
# ('internet', 1)
# ('migration', 1)
# ('investment', 1)
# ('land', 1)
# ('estimator', 1)
# ('decision', 1)
# ('knowledge', 1)
# ('organic', 1)
# ('donor', 1)
# ('between', 1)
# ('spatial', 1)
# ('poverty', 1)
# ('agriholding', 1)
# ('germany', 1)
# ('rent', 1)
# ('broadband', 1)
# ('program', 1)
# ('voter', 1)
# ('choice', 1)
# ('turkey', 1)
# ('birth', 1)
# ('tenant', 1)
# ('fibre', 1)
# ('farm', 1)
# ('operator', 1)
# ('index', 1)
# ('player', 1)
# ('system', 1)
# ('bond', 1)
# ('para', 1)
# ('sector', 1)
# ('scenario', 1)
# ('economy', 1)
# ('competition', 1)
# ('agricultural', 1)
# ('college', 1)
# ('innovation', 1)
# ('journal', 1)
# ('migrant', 1)
# ('election', 1)
# ('water', 1)
# ('breastfeeding', 1)
# ('2013', 1)
# ('typical', 1)
# ('debt', 1)
# ('user', 1)
# ('wave', 1)
# ('mobile', 1)
# ('monetary', 1)
# ('coffee', 1)
# ('task', 1)
# ('estimate', 1)
# ('sell', 1)
# ('behavior', 1)
# ('2014', 1)
# ('labmy', 1)
# ('united', 1)
# ('woman', 1)
# ('france', 1)
# ('participant', 1)
# ('utility', 1)
# ('food', 1)
# ('fund', 1)
# ('mission', 1)
# ('assessment', 1)
# ('english', 1)
# ('elp', 1)
# ('university', 1)
# ('italy', 1)
# ('unemployment', 1)
# ('survey', 1)
# ('company', 1)
# ('order', 1)
# ('teacher', 1)
# ('credit', 1)
# ('party', 1)
# ('spain', 1)
# ('coin', 1)
# ('vote', 1)
# ('literacy', 1)
# ('insurance', 1)
# ('offshoring', 1)
# ('renewable', 1)
# ('agent', 1)
# ('stock', 1)
# ('inequality', 1)
# ('return', 1)
# ('local', 1)
# ('board', 1)
# ('excl', 1)
# ('start', 1)
# ('farmer', 1)
# ('globalization', 1)
# ('power', 1)
# ('experiment', 1)
# ('volatility', 1)
# ('zealand', 1)
# ('other', 1)
# ('disaster', 1)
# ('forecast', 1)
# ('productivity', 1)
# ('family', 1)
# ('worker', 1)
# ('skill', 1)
# ('confidence', 1)
# ('political', 1)
# ('provider', 1)
# ('sovereign', 1)
# ('work', 1)
# ('tourism', 1)
# ('paperboard', 1)
# ('paper', 1)
# ('rating', 1)
# ('incentive', 1)
# ('contract', 1)
# ('earning', 1)
# ('candidate', 1)
# ('acces', 1)
# ('banking', 1)
# ('waste', 1)
# ('consumer', 1)

# %%
from os.path import isdir
import os
from collections import namedtuple
import json

class ConceptCorpus():
    def __init__(self, topicModel, path='samples'):
        if isdir(path):
            self.path = path
        else:
            raise AttributeError("{} is not a directory".format(path))
        
        self.topicModel = topicModel
        self.keywords = set()
        
        for f in self._fileIter():
            if 'subject' in f:
                self.keywords.update(f['subject'])
        self.keyword = list(self.keyword)

        
    def _fileIter():
        '''
        iterates over all files in self.path. return their content as python object.
        '''
        for f in os.scandir(self.path):
            if f.is_file():
                with open(f.name) as fd:
                    yield json.load(fd)
        
    def __getitem__(self, name):
        if name == keywords:
            return self.keywords
        else:
            raise AttributeError('This object has no attribute {}.'.format(name))
        
        
    def __iter__(self):
        for content in self._fileIter():
            if 'subject' in content and 'plaintext' in f:
                topicDistribution = lda.get_document_topics( \
                                        myCorpus.dictionary.doc2bow(f['plaintext'].split()))
                # return all that in a namedtuple

# %%
def fitConcepts(alpha=.5, workers=4, passes=25)
# Out:
#   File "<ipython-input-8-b9190031ae62>", line 1
#     def fitConcepts(alpha=.5, workers=4, passes=25)
#                                                    ^
# SyntaxError: invalid syntax
